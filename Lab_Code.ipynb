# %%
import numpy as np
import pandas as pd
import matplotlib as plot

# %%
days =   ['Mon','Tue','Wed','Thr','Fri','Sat','Sun']
temp =   [29,12,45,51,27,19,20]
    
x = pd.DataFrame({'Day':days,'Temp':temp})
x.plot(x='Day',y='Temp',kind='line')
# Out:
# <Axes: xlabel='Day'>
